# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 7, 9, 14, -1, 0, 6, -2, 10, 5, 5 , 5, 0])

# %%
a = np.array([ [1,2,7,9,4,8], [2,4,6,8,9,0] , [2,4,6,8,9,0], [2,4,6,8,9,1]])
b = np.array([ [2,4,6,8,9,1], [1,2,7,9,4,8] , [2,4,6,8,9,0], [2,4,6,8,9,1]])
plt.plot(a, b)
# Out:
# [<matplotlib.lines.Line2D at 0x1db6a81f790>,
#  <matplotlib.lines.Line2D at 0x1db6a81fa30>,
#  <matplotlib.lines.Line2D at 0x1db6a81f6a0>,
#  <matplotlib.lines.Line2D at 0x1db6a81fc70>,
#  <matplotlib.lines.Line2D at 0x1db6a81fdf0>,
#  <matplotlib.lines.Line2D at 0x1db675ce730>]

# %%
a = np.array([ [1,2,7,9,4,8], [2,4,6,8,9,0] ])
plt.plot(a[0],a[1])
plt.plot(a[0],a[1], 'ro')

# %%
plt.plot(a , b, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x1db6a5411c0>,
#  <matplotlib.lines.Line2D at 0x1db6a5411f0>,
#  <matplotlib.lines.Line2D at 0x1db6a541250>,
#  <matplotlib.lines.Line2D at 0x1db6a541310>,
#  <matplotlib.lines.Line2D at 0x1db6a5413d0>,
#  <matplotlib.lines.Line2D at 0x1db6a541490>]

# %%
plt.plot(a , b, 'sr')
# Out:
# [<matplotlib.lines.Line2D at 0x1db69d88940>,
#  <matplotlib.lines.Line2D at 0x1db69d88970>,
#  <matplotlib.lines.Line2D at 0x1db69d889d0>,
#  <matplotlib.lines.Line2D at 0x1db69d88a90>,
#  <matplotlib.lines.Line2D at 0x1db69d88b50>,
#  <matplotlib.lines.Line2D at 0x1db69d88c10>]

# %%
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.plot(a[0],a[1], 'b--')

# %%
t = np.linspace( 0,5, 20)
plt.plot( t, t**2, color='coral', linestyle='--')
plt.plot(t , 4*t, color='indigo', linewidth=2)

# %%
plt.subplot(1,3,1)
plt.plot(t,t,'c--')


plt.subplot(1,3,2)
plt.plot(t,-t**2,'y--')

# %%
plt.subplot(1,2,1)
plt.plot(t,t,'p-')

plt.subplot(1,4,4)
plt.plot(t,-t**3,'mo')

# %%
grades = {
    'John':20,
    'Paty':23,
    'Sonia':19,
    'Jesús':24,
    'Luis':23,
    'Pet':19,
    'David':25,
    'Paul':25
}
plt.bar(range(len(grades)), list(grades.values()), color='darkturquoise')
plt.xticks(range(len(grades)), list(grades.keys()))
plt.xlabel("Students")
plt.ylabel("Ages")
# Out:
# Text(0, 0.5, 'Ages')

# %%
x = np.random.randn(1000)
plt.hist(x, color='seagreen')
# Out:
# (array([ 15.,  41., 119., 199., 234., 218., 124.,  43.,   4.,   3.]),
#  array([-2.65800109, -2.05615019, -1.4542993 , -0.8524484 , -0.25059751,
#          0.35125339,  0.95310428,  1.55495518,  2.15680607,  2.75865697,
#          3.36050786]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-cbb1ed8e6894> in <module>
# ----> 1 plt.xtixks(range(len(grades)), list(grades.keys()))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtixks'
