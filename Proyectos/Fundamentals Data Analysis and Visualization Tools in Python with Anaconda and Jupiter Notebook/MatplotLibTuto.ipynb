# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 7, 9, 14, -1, 0, 6, -2, 10, 5, 5 , 5, 0])

# %%
a = np.array([ [1,2,7,9,4,8], [2,4,6,8,9,0] , [2,4,6,8,9,0] ])
b = np.array([ [2,4,6,8,9,1], [1,2,7,9,4,8] , [2,4,6,8,9,0] ])
plt.plot(a, b)

# %%
a = np.array([ [1,2,7,9,4,8], [2,4,6,8,9,0] ])
plt.plot(a[0],a[1])
plt.plot(a[0],a[1], 'ro')

# %%
plt.plot(a , b, 'ro')

# %%
plt.plot(a , b, 'sr')
